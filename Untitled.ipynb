# %%
import pandas as pd

# %%
df = pd.read_csv("downloads/protein-coding_gene.txt", delimiter="\t",  usecols=[0, 1] )

# %%
df.loc[df['name2'] == g]
# Out:
#       hgnc_id   symbol
# 0      HGNC:5     A1BG
# 1  HGNC:24086     A1CF
# 2      HGNC:7      A2M
# 3  HGNC:23336    A2ML1
# 4  HGNC:30005  A3GALT2

# %%
result = df.loc[df['symbol'] == "A1BG"]

# %%
result['hgnc_id'].to_string(index=False).lstrip()
# Out:
# u'HGNC:5'

# %%
import argparse
import csv
import collections
import httplib2 as http
import json
import time
import os
import pandas as pd
pd.options.mode.chained_assignment = None
try:
    from urlparse import urlparse
except ImportError:
    from urllib.parse import urlparse

# %%
def run_query(gene):
        headers = {'Accept': 'application/json',}
        uri = 'http://rest.genenames.org'
        path = '/search/prev_symbol/' + gene
        target = urlparse(uri+path)
        method = 'GET'
        body = ''
        h = http.Http()
        response, content = h.request(target.geturl(),method,body,headers)
        notfound = []
        if response['status'] == '200':
        # parse content with the json module 
            data = json.loads(content)
            if len(data['response']['docs']) != 0:
                print "%s was found in previous symbol. Could the new symbol be:%s" % (gene, data['response']['docs'][0]['symbol'])
            else:
                notfound.append(gene)
        else:
            print 'Error detected: ' + response['status']
        if len(notfound) != 0:
            print "!! %s were not found in the database." % (','.join(notfound))

# %%
run_query("ARMC4")
# Out:
# ARMC4 was found in previous symbol. Could the new symbol be:ODAD2
# ('ARMC4', u'HGNC:25583')

# %%
df1 = pd.read_csv("downloads/RefseqSelect_GRCh37.txt",sep="\t", dtype={'#bin':int,'name':str,'chrom':str,'strand':str,'txStart':int,'txEnd':int,'cdsStart':int,'cdsEnd':int,'exonCount':int,'exonStarts':str,'exonEnds':str, 'score':int,   'name2':str ,  'cdsStartStat':str ,   'cdsEndStat':str ,'exonFrames':str})
df2 = pd.read_csv("downloads/RefseqAll_GRCh37.txt",sep="\t", dtype={'#bin':int,'name':str,'chrom':str,'strand':str,'txStart':int,'txEnd':int,'cdsStart':int,'cdsEnd':int,'exonCount':int,'exonStarts':str,'exonEnds':str, 'score':int,   'name2':str ,  'cdsStartStat':str ,   'cdsEndStat':str ,'exonFrames':str})
df3 = pd.read_csv("downloads/GenCodeBasicV36lift37.txt",sep="\t", dtype={'#bin':int,'name':str,'chrom':str,'strand':str,'txStart':int,'txEnd':int,'cdsStart':int,'cdsEnd':int,'exonCount':int,'exonStarts':str,'exonEnds':str, 'score':int,   'name2':str ,  'cdsStartStat':str ,   'cdsEndStat':str ,'exonFrames':str})
df1 = df1[:10]
df2 = df2[:10]
df3 = df3[:10]

# %%
df1
# Out:
#    #bin            name chrom strand    txStart      txEnd   cdsStart  \
# 0     0     NM_032291.4     1      +   66999835   67216822   67000041
# 1     1  NM_001080397.2     1      +    8378144    8404227    8378168
# 2     1     NM_018090.5     1      +   16767218   16786573   16767256
# 3     1     NM_013943.3     1      +   25071937   25170812   25072044
# 4     1     NM_052998.4     1      +   33546753   33589093   33547850
# 5     1     NM_032785.4     1      -   48998525   50489626   48999844
# 6     2     NM_003243.5     1      -   92145899   92351708   92149295
# 7     2     NM_001918.4     1      -  100652474  100715390  100661810
# 8     3     NM_021222.3     1      +  150980924  151008189  150981108
# 9     3     NM_022457.7     1      -  175913966  176176422  175914288
#
#       cdsEnd  exonCount                                         exonStarts  \
# 0   67208778         25  66999835,67091529,67098752,67101626,67105459,6...
# ...

# %%
df2
# Out:
#    #bin            name chrom strand   txStart     txEnd  cdsStart    cdsEnd  \
# 0     0  NM_001308203.2     1      +  66999275  67216822  67000041  67208778
# 1     0  NM_001350218.2     1      +  66999835  67216822  67000041  67208778
# 2     0     NM_032291.4     1      +  66999835  67216822  67000041  67208778
# 3     0  NM_001350217.2     1      +  66999835  67216822  67000041  67208778
# 4     1  NM_001080397.2     1      +   8378144   8404227   8378168   8404073
# 5     1  NM_001145278.1     1      +  16767166  16786585  16767256  16785385
# 6     1  NM_001145277.1     1      +  16767166  16786585  16767256  16785491
# 7     1     NM_018090.5     1      +  16767218  16786573  16767256  16785385
# 8     1     NM_013943.3     1      +  25071937  25170812  25072044  25167428
# 9     1  NM_001293562.2     1      +  33546753  33589093  33547850  33585783
#
#    exonCount                                         exonStarts  \
# ...

# %%
df3
# Out:
#    #bin                  name chrom strand   txStart     txEnd  cdsStart  \
# 0     0  ENST00000237247.10_2     1      +  66999065  67210057  67000041
# 1     0   ENST00000371039.5_2     1      +  66999274  67210768  67000041
# 2     0   ENST00000371037.9_2     1      +  66999835  67216822  67000041
# 3     1   ENST00000471889.7_4     1      +   8378173   8404225   8384389
# 4     1   ENST00000289877.8_3     1      +   8384389   8404227   8384389
# 5     1   ENST00000504551.6_1     1      +  16767215  16785503  16767256
# 6     1   ENST00000457722.6_1     1      +  16767218  16785568  16767256
# 7     1  ENST00000337132.10_2     1      +  16767218  16786573  16767256
# 8     1   ENST00000443980.6_1     1      +  16767230  16786572  16767256
# 9     1   ENST00000374379.9_2     1      +  25071937  25170812  25072044
#
#      cdsEnd  exonCount                                         exonStarts  \
# 0  67208778         27  66999065,66999928,67091529,67098752,67099762,6...
# ...

# %%
listOfTuples = []
for index, row in df2.iterrows():
            for c, (i,j) in enumerate(zip(row['exonStarts'].split(',')[:-1], row['exonEnds'].split(',')[:-1])):
                listOfTuples.append(tuple(row[0:2]) + (row[2], ) + tuple(row[3:8]) + (1, i , j) + (row[11],row[12]+'_E' + str(c + 1)) + tuple(row[13:15])+ (row[15].split(',')[c],))

# %%
listOfTuples
# Out:
# [(0,
#   'NM_001308203.2',
#   '1',
#   '+',
#   66999275,
#   67216822,
#   67000041,
#   67208778,
#   1,
#   '66999275',
#   '66999355',
#   0,
#   'SGIP1_E1',
#   'cmpl',
#   'cmpl',
#   '-1'),
#  (0,
#   'NM_001308203.2',
#   '1',
#   '+',
#   66999275,
#   67216822,
#   67000041,
#   67208778,
#   1,
#   '66999928',
#   '67000051',
#   0,
#   'SGIP1_E2',
#   'cmpl',
#   'cmpl',
#   '0'),
#  (0,
#   'NM_001308203.2',
#   '1',
#   '+',
#   66999275,
#   67216822,
#   67000041,
#   67208778,
#   1,
#   '67091529',
#   '67091593',
#   0,
#   'SGIP1_E3',
#   'cmpl',
#   'cmpl',
#   '1'),
#  (0,
#   'NM_001308203.2',
#   '1',
#   '+',
#   66999275,
#   67216822,
#   67000041,
#   67208778,
#   1,
#   '67098752',
#   '67098777',
#   0,
#   'SGIP1_E4',
#   'cmpl',
#   'cmpl',
#   '2'),
#  (0,
#   'NM_001308203.2',
#   '1',
#   '+',
#   66999275,
#   67216822,
#   67000041,
#   67208778,
#   1,
#   '67105459',
#   '67105516',
#   0,
#   'SGIP1_E5',
#   'cmpl',
#   'cmpl',
#   '0'),
# ...
